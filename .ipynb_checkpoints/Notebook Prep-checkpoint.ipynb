# %% [markdown]
# # Machine Learning for San Diego

# %%
# Standard Packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import datetime
import glob

import warnings
warnings.filterwarnings('ignore')

# Word Cloud
import nltk
from wordcloud import WordCloud
from nltk.corpus import stopwords

nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Ryan\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
path = 'C:/Users/Ryan/Documents/Github/ML-SD-Project/'
#path = 'C:/Users/Ryan Luu/Documents/Github/ML-SD-Project/'

all_files = glob.glob(path + "data/*.csv")

li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)

raw = pd.concat(li, axis=0, ignore_index=True)

# %%
raw.head()
# Out:
#    service_request_id  service_request_parent_id  sap_notification_number  \
# 0               80477                        NaN                      NaN
# 1               80478                        NaN                      NaN
# 2               80479                        NaN                      NaN
# 3               80480                        NaN                      NaN
# 4               80481                        NaN                      NaN
#
#         date_requested  case_age_days       service_name case_record_type  \
# 0  2016-05-20T00:08:00           15.0              Other              TSW
# 1  2016-05-20T05:04:00            NaN      Parking Meter              TSW
# 2  2016-05-20T05:05:00            NaN  72 Hour Violation          Parking
# 3  2016-05-20T05:05:00            NaN        Dead Animal              TSW
# 4  2016-05-20T05:06:00            0.0   Graffiti Removal              TSW
#
#           date_updated    status        lat         lng  council_district  \
# 0  2016-06-03T00:00:00    Closed        NaN         NaN               NaN
# 1                  NaN  Referred  32.726553 -117.125296               3.0
# 2                  NaN  Referred  32.726523 -117.125532               3.0
# 3                  NaN  Referred  32.726365 -117.125478               3.0
# 4  2016-05-20T00:00:00    Closed  32.726445 -117.125476               3.0
#
#    comm_plan_code       comm_plan_name park_name case_origin referred  \
# 0             NaN                  NaN       NaN       Email      NaN
# 1             8.0  Greater Golden Hill       NaN      Mobile      NaN
# 2             8.0  Greater Golden Hill       NaN      Mobile      NaN
# 3             8.0  Greater Golden Hill       NaN      Mobile      NaN
# 4             8.0  Greater Golden Hill       NaN      Mobile      NaN
#
#                                   public_description
# 0  Name :  JackEmail :  bcjack@hotmail.comAddress...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                               Test

# %%
print("There are " + str(raw.shape[0]) + " observations and " + str(raw.shape[1]) + " variables.")
# Out:
# There are 681427 observations and 18 variables.

# %% [markdown]
# # Data Cleaning and Manipulation

# %%
# Remove unnecessary columns
raw = raw.drop(["service_request_id", "service_request_parent_id", "sap_notification_number",'referred'], axis=1)

# %%
df = raw
# Convert back into datetime64
df['date_requested'] = pd.to_datetime(df['date_requested'])

# Extract date, month, time
df['date'] = df.date_requested.dt.date 
df['month'] = df.date_requested.dt.month
df['time'] = df.date_requested.dt.time

# Better Season
def gs(x):
    if (x == 12) or (x < 3):
        return 'Winter'
    elif (x >= 3) and (x < 6):
        return 'Spring'
    elif (x >= 6) and (x < 9):
        return 'Summer'
    elif (x >= 9) and (x < 12):
        return 'Fall'
    else: 
        return 'Error'

df['season'] = df.month.apply(lambda x: gs(x))

# Time of the Day Variable
def gt(x):
    if (x >= 0) and (x <= 5):
        return 'Past Midnight'
    elif (x > 5) and (x <= 11):
        return 'Morning'
    elif (x > 11) and (x <= 17):
        return 'Afternoon'
    elif (x > 17) and (x <= 23):
        return 'Evening'

df['tod'] = df.date_requested.dt.hour.apply(lambda x: gt(x))

# Make new DOW (day of week) variable
df['dow'] = df.date.apply(lambda x: pd.Timestamp(str(x)).weekday_name)

# Lowercase public description
df.public_description = df.public_description.apply(lambda x: str(x).lower())

# Month 
df.month[df.month == 1] = 'Jan'
df.month[df.month == 2] = 'Feb'
df.month[df.month == 3] = 'Mar'
df.month[df.month == 4] = 'Apr'
df.month[df.month == 5] = 'May'
df.month[df.month == 6] = 'Jun'
df.month[df.month == 7] = 'Jul'
df.month[df.month == 8] = 'Aug'
df.month[df.month == 9] = 'Jan'
df.month[df.month == 10] = 'Oct'
df.month[df.month == 11] = 'Nov'
df.month[df.month == 12] = 'Dec'

#Cleaning and replacing nan in council district with 0
df['council_district'] = df.council_district.fillna(0)
df['council_district'] = df.council_district.astype(np.int64)
df['council_district'] = df.council_district.apply(lambda x: 'district ' + str(x))

# Remove 'Test' observations from public description
df = df[~df.public_description.str.contains('test')]

# Cleaning and Remove nan obsertation in case age days
df = df.dropna(subset=['case_age_days'])
df['case_age_days'] = df.case_age_days.astype(np.int64)

# Setting Conditions for Dataframe
df['lat'] = df['lat'].astype(float)
df['lng'] = df['lng'].astype(float)
df2 = df[(df['lat'] > 32.5444) &
        (df['lat'] < 33.4274) &
        (df['lng'] < -117.0301) &
        (df['lng'] > -117.6126) &
        (df['status'] == 'Closed')]

df2.tail()
# Out:
#             date_requested  case_age_days       service_name  \
# 681420 2019-12-31 23:08:00              1                NaN
# 681422 2019-12-31 23:28:00              1    Citizen Contact
# 681423 2019-12-31 23:32:00              6  72 Hour Violation
# 681424 2019-12-31 23:35:00              1    Citizen Contact
# 681425 2019-12-31 23:45:00              2    Illegal Dumping
#
#             case_record_type         date_updated  status        lat  \
# 681420               Parking  2020-01-02T00:00:00  Closed  32.799915
# 681422               Parking  2020-01-02T00:00:00  Closed  32.707425
# 681423               Parking  2020-01-07T00:00:00  Closed  32.767174
# 681424               Parking  2020-01-02T00:00:00  Closed  32.751146
# 681425  ESD Complaint/Report  2020-01-03T00:00:00  Closed  32.709147
#
#                lng council_district  comm_plan_code           comm_plan_name  \
# 681420 -117.244770       district 2            27.0            Pacific Beach
# 681422 -117.093231       district 4            11.0    Encanto Neighborhoods
# 681423 -117.122808       district 3            59.0  Mid-City:Normal Heights
# 681424 -117.250123       district 2            23.0              Ocean Beach
# 681425 -117.059223       district 4            11.0    Encanto Neighborhoods
#
#        park_name case_origin  \
# 681420       NaN      Mobile
# 681422       NaN      Mobile
# 681423       NaN      Mobile
# 681424       NaN      Mobile
# 681425       NaN      Mobile
#
#                                        public_description        date month  \
# 681420   fireworks in the joint use field on or around ..  2019-12-31   Dec
# 681422  loud fireworks and loud music coming fromel re...  2019-12-31   Dec
# 681423  car has been parked for at least two weeks in ...  2019-12-31   Dec
# 681424  apartment residents are throwing fireworks at ...  2019-12-31   Dec
# 681425                                                nan  2019-12-31   Dec
#
#             time  season      tod      dow
# 681420  23:08:00  Winter  Evening  Tuesday
# 681422  23:28:00  Winter  Evening  Tuesday
# 681423  23:32:00  Winter  Evening  Tuesday
# 681424  23:35:00  Winter  Evening  Tuesday
# 681425  23:45:00  Winter  Evening  Tuesday

# %%
#df2.to_csv(path + "data/get_it_done_full.csv", encoding='utf-8', index=False)

# %% [markdown]
# # Exploratory Data Analysis

# %%
a= sns.catplot(y = 'service_name',
           kind = 'count',
           height = 8,
           aspect = 1.5,
           order = df2.service_name.value_counts().head(12).index,
           data = df2)
plt.title("Top 12 Service Request")
a.set(xlabel='Frequency', ylabel='Service Request')

# %%
a = sns.catplot(x='month',
            kind='count',
            height=8, 
            aspect=1.5,
            data=df2)

plt.title("Frequency of Requests by Months")
a.set(xlabel="Months",ylabel="Frequency")
plt.show()

# %%
a = sns.catplot(x='dow',
            kind='count',
            height=8, 
            aspect=1.5,
            data=df2)

plt.title("Frequency of Requests by Weekdays")
a.set(xlabel="Months",ylabel="Frequency")
plt.show()

# %%
a = sns.catplot(x='season',
            kind='count',
            height=8, 
            aspect=1.5,
            data=df2)

plt.title("Frequency of Requests by Seasons")
a.set(xlabel="Seasons",ylabel="Frequency")
plt.show()

# %%
c = sns.lineplot(x="month",
                y="case_age_days",
                hue='dow',
                data=df2
                ).set_title('Average Case age days throughout 2019')
plt.show()

# %% [markdown]
# # WordCloud

# %%
# Clean nan from public description
desc = ((df2[~df2.public_description.str.contains('nan')])['public_description'])
string = desc.to_string()

# %%
s = stopwords.words('english')
print(s)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
wordcloud = WordCloud(stopwords = s, background_color='white').generate(string)

# Plot
plt.figure(figsize=(11,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# # Preparing New Dataframe

# %%
df2.head()
# Out:
#         date_requested  case_age_days  \
# 17 2016-05-20 07:19:00             14
# 32 2016-05-20 09:07:00              0
# 33 2016-05-20 09:10:00            537
# 36 2016-05-20 09:20:00              6
# 37 2016-05-20 09:24:00            987
#
#                                         service_name case_record_type  \
# 17                                  Graffiti Removal              TSW
# 32                                      Damaged Curb              TSW
# 33  Storm Water Code Enforcement - Illegal Discharge              TSW
# 36                           Traffic Sign - Maintain              TSW
# 37                          Evaluate for Resurfacing              TSW
#
#            date_updated  status        lat         lng council_district  \
# 17  2016-06-03T00:00:00  Closed  32.735047 -117.080075       district 4
# 32  2016-05-20T00:00:00  Closed  32.747350 -117.128953       district 3
# 33  2017-11-08T00:00:00  Closed  32.801410 -117.233518       district 2
# 36  2016-05-26T00:00:00  Closed  32.913842 -117.113892       district 5
# 37  2019-01-31T00:00:00  Closed  32.919712 -117.114320       district 5
#
#     comm_plan_code         comm_plan_name park_name case_origin  \
# 17            57.0  Mid-City:Eastern Area       NaN       Phone
# 32            28.0             North Park       NaN      Mobile
# 33            27.0          Pacific Beach       NaN       Phone
# 36            34.0  Scripps Miramar Ranch       NaN       Phone
# 37            34.0  Scripps Miramar Ranch       NaN       Phone
#
#                               public_description        date month      time  \
# 17  graffiti on the wall in front of the library  2016-05-20   May  07:19:00
# 32                                           nan  2016-05-20   May  09:07:00
# 33                                           nan  2016-05-20   May  09:10:00
# 36  construction sign face down in center medien  2016-05-20   May  09:20:00
# 37            lots of cracks and missing asphalt  2016-05-20   May  09:24:00
#
#     season      tod     dow
# 17  Spring  Morning  Friday
# 32  Spring  Morning  Friday
# 33  Spring  Morning  Friday
# 36  Spring  Morning  Friday
# 37  Spring  Morning  Friday

# %%
# Normalize function
def norm(x):
    r = (x-min(x))/(max(x)-min(x))
    return(r)

# %%
# Convert into categorical
df2['season'] = df['season'].astype('category')
df2['dow'] = df['dow'].astype('category')
df2['case_record_type'] = df['case_record_type'].astype('category')
df2['council_district'] = df['council_district'].astype('category')
df2['month'] = df['month'].astype('category')
df2['case_origin'] = df['case_origin'].astype('category')
df2['service_name'] = df['service_name'].astype('category')

# %%
df3 = pd.get_dummies(df2, columns=['dow'], prefix = [None])
df3 = pd.get_dummies(df3, columns=['month'], prefix = [None])
df3 = pd.get_dummies(df3, columns=['season'], prefix = [None])
df3 = pd.get_dummies(df3, columns=['council_district'], prefix = [None])
df3 = pd.get_dummies(df3, columns =['case_origin'], prefix = [None])
df3 = pd.get_dummies(df3, columns = ['comm_plan_name'], prefix = [None])
df3 = pd.get_dummies(df3, columns = ['tod'], prefix = [None])

df3['normLat'] = norm(df3.lat)
df3['normLng'] = norm(df3.lng)

df3.head()
# Out:
#         date_requested  case_age_days  \
# 17 2016-05-20 07:19:00             14
# 32 2016-05-20 09:07:00              0
# 33 2016-05-20 09:10:00            537
# 36 2016-05-20 09:20:00              6
# 37 2016-05-20 09:24:00            987
#
#                                         service_name case_record_type  \
# 17                                  Graffiti Removal              TSW
# 32                                      Damaged Curb              TSW
# 33  Storm Water Code Enforcement - Illegal Discharge              TSW
# 36                           Traffic Sign - Maintain              TSW
# 37                          Evaluate for Resurfacing              TSW
#
#            date_updated  status        lat         lng  comm_plan_code  \
# 17  2016-06-03T00:00:00  Closed  32.735047 -117.080075            57.0
# 32  2016-05-20T00:00:00  Closed  32.747350 -117.128953            28.0
# 33  2017-11-08T00:00:00  Closed  32.801410 -117.233518            27.0
# 36  2016-05-26T00:00:00  Closed  32.913842 -117.113892            34.0
# 37  2019-01-31T00:00:00  Closed  32.919712 -117.114320            34.0
#
#    park_name  ... Torrey Pines University Uptown  Via De La Valle  Afternoon  \
# 17       NaN  ...            0          0      0                0          0
# 32       NaN  ...            0          0      0                0          0
# 33       NaN  ...            0          0      0                0          0
# 36       NaN  ...            0          0      0                0          0
# 37       NaN  ...            0          0      0                0          0
#
#     Evening  Morning  Past Midnight   normLat   normLng
# 17        0        1              0  0.252822  0.858126
# 32        0        1              0  0.269138  0.719367
# 33        0        1              0  0.340828  0.422515
# 36        0        1              0  0.489928  0.762122
# 37        0        1              0  0.497712  0.760908
#
# [5 rows x 138 columns]

# %%
# Drop column not needed for training
df3 = df3.drop(["date_requested", "case_age_days", "service_name",'date_updated', 'status',
                'lat','lng','comm_plan_code','park_name',
               'public_description','date','time'], axis=1)

# %%
df3.head()
# Out:
#    case_record_type  Friday  Monday  Saturday  Sunday  Thursday  Tuesday  \
# 17              TSW       1       0         0       0         0        0
# 32              TSW       1       0         0       0         0        0
# 33              TSW       1       0         0       0         0        0
# 36              TSW       1       0         0       0         0        0
# 37              TSW       1       0         0       0         0        0
#
#     Wednesday  Apr  Aug  ...  Torrey Pines  University  Uptown  \
# 17          0    0    0  ...             0           0       0
# 32          0    0    0  ...             0           0       0
# 33          0    0    0  ...             0           0       0
# 36          0    0    0  ...             0           0       0
# 37          0    0    0  ...             0           0       0
#
#     Via De La Valle  Afternoon  Evening  Morning  Past Midnight   normLat  \
# 17                0          0        0        1              0  0.252822
# 32                0          0        0        1              0  0.269138
# 33                0          0        0        1              0  0.340828
# 36                0          0        0        1              0  0.489928
# 37                0          0        0        1              0  0.497712
#
#      normLng
# 17  0.858126
# 32  0.719367
# 33  0.422515
# 36  0.762122
# 37  0.760908
#
# [5 rows x 126 columns]

# %%
# View unique classes
df3.case_record_type.unique()
# Out:
# [TSW, Parking, ESD Complaint/Report, Traffic Engineering, DSD, TSW ROW, Storm Water Code Enforcement]
# Categories (7, object): [TSW, Parking, ESD Complaint/Report, Traffic Engineering, DSD, TSW ROW, Storm Water Code Enforcement]

# %%
# Convert case_record_type into integer category
def dep(x):
    if x == 'TSW':
        return 0
    if x == 'Parking':
        return 1
    if x == 'ESD Complaint/Report':
        return 2
    if x == 'Traffic Engineering':
        return 3
    if x == 'DSD':
        return 4
    if x == 'TSW ROW':
        return 5
    if x == 'Storm Water Code Enforcement':
        return 6
    
df3.case_record_type = df3.case_record_type.apply(lambda x: dep(x))

# %%
df3.tail()
# Out:
#        case_record_type  Friday  Monday  Saturday  Sunday  Thursday  Tuesday  \
# 681420                1       0       0         0       0         0        1
# 681422                1       0       0         0       0         0        1
# 681423                1       0       0         0       0         0        1
# 681424                1       0       0         0       0         0        1
# 681425                2       0       0         0       0         0        1
#
#         Wednesday  Apr  Aug  ...  Torrey Pines  University  Uptown  \
# 681420          0    0    0  ...             0           0       0
# 681422          0    0    0  ...             0           0       0
# 681423          0    0    0  ...             0           0       0
# 681424          0    0    0  ...             0           0       0
# 681425          0    0    0  ...             0           0       0
#
#         Via De La Valle  Afternoon  Evening  Morning  Past Midnight   normLat  \
# 681420                0          0        1        0              0  0.338846
# 681422                0          0        1        0              0  0.216192
# 681423                0          0        1        0              0  0.295427
# 681424                0          0        1        0              0  0.274173
# 681425                0          0        1        0              0  0.218476
#
#          normLng
# 681420  0.390570
# 681422  0.820778
# 681423  0.736812
# 681424  0.375375
# 681425  0.917324
#
# [5 rows x 126 columns]

# %% [markdown]
# # Machine Learning Time!

# %% [markdown]
# #### Packages

# %%
# ML Packages
import tensorflow as tf
from tensorflow import keras

import scipy
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import NearMiss
from collections import Counter

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# #### Test and Train Split

# %% [markdown]
# Hold-out method: Create train and test sets. Train the model with the train set and test on test set. Because of imbalanced classifers, I will be using scikit-learn's stratified train/test split to ensure that the train and test sets have approximately the same percentage of samples of each target class as the complete set.

# %%
# Change df3 into np.array & convert to float
np.random.seed(1234)
df3_nparray = df3.values

df3x = (df3_nparray[:,1:]).astype('float32')
df3y = (df3_nparray[:,[0]]).astype('float32')

# %%
# Stratified splitting
trainx, testx, trainy, testy = train_test_split(df3x, df3y,
                                                stratify=df3y,
                                                test_size=0.3)

# %% [markdown]
# #### Functions

# %%
# Accuracy Report
def cm_report(x,y):
    print('Accuracy Score: ', accuracy_score(x,y))
    print()
    print('Report')
    print(classification_report(x,y))

labels = ['TSW 0', 'Parking 1', 'ESD Complaint/Report 2', 'Traffic Engineering 3',
          'DSD 4', 'TSW ROW 5', 'Storm Water Code Enforcement 6']

# Prediction Report    
def pred_report(x):
    print('Prediction Report')
    print('')
    prediction = x.predict_proba(testx)
    predictiondf = pd.DataFrame(data=prediction)
    predictiondf.rename(columns={i:j for i,j in zip(predictiondf.columns,labels)}, inplace = True)
    predictiondf['Class_Prediction'] = [labels[np.argmax(i)] for i in prediction]
    predictiondf['Pred'] = [int(labels[np.argmax(i)][-1:]) for i in prediction]
    predictiondf['Prob'] = [np.max(i) for i in prediction]
    predictiondf['Actual'] = testy.astype(int)
    predictiondf['Score'] = np.where(predictiondf.Actual == predictiondf.Pred, True, False)
    print(predictiondf.head(10))
    print('')
    
    predict = predictiondf.Pred.values
    actual = predictiondf.Actual.values
    cm_report(actual,predict)

# %% [markdown]
# # Neural Network

# %%
nn_model = keras.Sequential([
    keras.layers.Flatten(input_shape=(125, )),
    keras.layers.Dense(128, activation=tf.nn.relu), #Rectified linear unit, common activation function
    #keras.layers.Dense(1, activation=tf.nn.relu),
    keras.layers.Dense(7, activation=tf.nn.softmax) # 7 classes in predicting service request type
])

nn_model.compile(optimizer='adam',
             loss = 'sparse_categorical_crossentropy', # multiclass prediction
             metrics=['accuracy'])

# %%
nn_model.fit(trainx, trainy, epochs=10)
# Out:
# Train on 332173 samples
# Epoch 1/10
# 332173/332173 [==============================] - 7s 22us/sample - loss: 0.8903 - accuracy: 0.6344
# Epoch 2/10
# 332173/332173 [==============================] - 7s 21us/sample - loss: 0.8649 - accuracy: 0.6437
# Epoch 3/10
# 332173/332173 [==============================] - 8s 23us/sample - loss: 0.8596 - accuracy: 0.6460
# Epoch 4/10
# 332173/332173 [==============================] - 7s 21us/sample - loss: 0.8564 - accuracy: 0.6474
# Epoch 5/10
# 332173/332173 [==============================] - 7s 22us/sample - loss: 0.8533 - accuracy: 0.6490
# Epoch 6/10
# 332173/332173 [==============================] - 7s 21us/sample - loss: 0.8513 - accuracy: 0.6485
# Epoch 7/10
# 332173/332173 [==============================] - 7s 20us/sample - loss: 0.8494 - accuracy: 0.6493
# Epoch 8/10
# 332173/332173 [==============================] - 7s 20us/sample - loss: 0.8477 - accuracy: 0.6503
# Epoch 9/10
# 332173/332173 [==============================] - 7s 20us/sample - loss: 0.8466 - accuracy: 0.6508
# Epoch 10/10
# 332173/332173 [==============================] - 7s 20us/sample - loss: 0.8452 - accuracy: 0.6513

# %%
train_loss, train_acc = nn_model.evaluate(trainx, trainy)

print('Train accuracy:', train_acc)
# Out:
# 332173/332173 [==============================] - 4s 13us/sample - loss: 0.8394 - accuracy: 0.6539
# Train accuracy: 0.6539243

# %%
test_loss, test_acc = nn_model.evaluate(testx, testy)

print('Test accuracy:', test_acc)
# Out:
# 142361/142361 [==============================] - 2s 12us/sample - loss: 0.8613 - accuracy: 0.6462
# Test accuracy: 0.6462093

# %%
pred_report(nn_model)
# Out:
# Prediction Report
#
#       TSW 0  Parking 1  ESD Complaint/Report 2  Traffic Engineering 3  \
# 0  0.725108   0.120971                0.092535               0.052712
# 1  0.522824   0.156093                0.279625               0.038033
# 2  0.999190   0.000707                0.000090               0.000005
# 3  0.189197   0.002623                0.804019               0.001163
# 4  0.271389   0.005532                0.716391               0.004766
# 5  0.999905   0.000088                0.000002               0.000001
# 6  0.482003   0.343294                0.115785               0.034920
# 7  0.504721   0.331272                0.085325               0.042177
# 8  0.475383   0.358027                0.138144               0.020950
# 9  0.414616   0.434280                0.129779               0.014477
#
#           DSD 4     TSW ROW 5  Storm Water Code Enforcement 6  \
# 0  1.652983e-03  2.211683e-03                        0.004810
# 1  2.266041e-03  7.492832e-04                        0.000411
# 2  1.191089e-11  1.187830e-08                        0.000009
# 3  1.609720e-05  2.874913e-04                        0.002694
# 4  6.955289e-06  2.881290e-05                        0.001886
# 5  3.984335e-15  2.223666e-10                        0.000004
# 6  1.468192e-02  4.345801e-04                        0.008882
# 7  1.182054e-02  6.722150e-03                        0.017962
# 8  1.520937e-03  1.642152e-03                        0.004333
# 9  4.557548e-04  4.092473e-03                        0.002300
#
#          Class_Prediction  Pred      Prob  Actual  Score
# 0                   TSW 0     0  0.725108       1  False
# 1                   TSW 0     0  0.522824       1  False
# 2                   TSW 0     0  0.999190       0   True
# 3  ESD Complaint/Report 2     2  0.804019       0  False
# 4  ESD Complaint/Report 2     2  0.716391       2   True
# 5                   TSW 0     0  0.999905       0   True
# 6                   TSW 0     0  0.482003       0   True
# 7                   TSW 0     0  0.504721       1  False
# 8                   TSW 0     0  0.475383       1  False
# 9               Parking 1     1  0.434280       1   True
#
# Accuracy Score:  0.646209284846271
#
# Report
#               precision    recall  f1-score   support
#
#            0       0.65      0.88      0.75     80269
#            1       0.47      0.23      0.31     26707
#            2       0.71      0.49      0.58     30255
#            3       0.64      0.10      0.18      3062
#            4       0.00      0.00      0.00       374
#            5       0.44      0.02      0.03       424
#            6       0.97      0.21      0.35      1270
#
#     accuracy                           0.65    142361
#    macro avg       0.55      0.27      0.31    142361
# weighted avg       0.63      0.65      0.61    142361

# %% [markdown]
# # Synthetic Minority Oversampling Technique

# %% [markdown]
# Looking at the accuracy report above, we can see that the model has high precision for some classes, but not for others. Down below is a graph that illustrates the Case Record Type class distribution. To combat this, I will use SMOTE to oversample the minority class. In doing so, I hope to better train the model in predicting minority classes.

# %%
a = sns.catplot(y='case_record_type',
            kind='count',
            height=8, 
            aspect=1.5,
            order = df2.case_record_type.value_counts().index,
            data=df2)

plt.title("Case Record Type Distribution")
a.set(xlabel="Case Types",ylabel="Frequency")
plt.show()

# %%
# Oversample with SMOTE
sm = SMOTE(random_state=42)
trainx_res, trainy_res = sm.fit_resample(trainx, trainy)

# %%
print('New Class Distribution %s' % Counter(trainy_res))
# Out:
# New Class Distribution Counter({2.0: 187294, 5.0: 187294, 0.0: 187294, 1.0: 187294, 3.0: 187294, 6.0: 187294, 4.0: 187294})

# %% [markdown]
# # Training Neural Network using SMOTE train set

# %%
# fit() -> trains the model
nn_model.fit(trainx_res, trainy_res, epochs=10)
# Out:
# Train on 1311058 samples
# Epoch 1/10
# 1311058/1311058 [==============================] - 41s 31us/sample - loss: 0.9775 - accuracy: 0.6349
# Epoch 2/10
# 1311058/1311058 [==============================] - 42s 32us/sample - loss: 0.8396 - accuracy: 0.6805
# Epoch 3/10
# 1311058/1311058 [==============================] - 40s 30us/sample - loss: 0.8017 - accuracy: 0.6928
# Epoch 4/10
# 1311058/1311058 [==============================] - 39s 30us/sample - loss: 0.7826 - accuracy: 0.6988
# Epoch 5/10
# 1311058/1311058 [==============================] - 39s 30us/sample - loss: 0.7695 - accuracy: 0.7031
# Epoch 6/10
# 1311058/1311058 [==============================] - 39s 30us/sample - loss: 0.7598 - accuracy: 0.7067
# Epoch 7/10
# 1311058/1311058 [==============================] - 39s 30us/sample - loss: 0.7519 - accuracy: 0.7093
# Epoch 8/10
# 1311058/1311058 [==============================] - 38s 29us/sample - loss: 0.7463 - accuracy: 0.7112
# Epoch 9/10
# 1311058/1311058 [==============================] - 39s 29us/sample - loss: 0.7412 - accuracy: 0.7132
# Epoch 10/10
# 1311058/1311058 [==============================] - 39s 30us/sample - loss: 0.7367 - accuracy: 0.7145

# %%
train_loss, train_acc = nn_model.evaluate(trainx_res, trainy_res)

print('Train accuracy:', train_acc)
# Out:
# 1311058/1311058 [==============================] - 22s 17us/sample - loss: 0.7319 - accuracy: 0.7179
# Train accuracy: 0.7178668

# %%
test_loss, test_acc = nn_model.evaluate(testx, testy)

print('Test accuracy:', test_acc)
# Out:
# 142361/142361 [==============================] - 2s 17us/sample - loss: 1.2109 - accuracy: 0.4869
# Test accuracy: 0.48686087

# %%
pred_report(nn_model)
# Out:
# Prediction Report
#
#       TSW 0  Parking 1  ESD Complaint/Report 2  Traffic Engineering 3  \
# 0  0.457314   0.210675                0.115709           1.945759e-01
# 1  0.201571   0.199374                0.341761           2.471786e-01
# 2  0.999074   0.000803                0.000123           1.050400e-16
# 3  0.097484   0.000782                0.898682           2.262739e-05
# 4  0.051134   0.007437                0.711711           6.135583e-02
# 5  0.999872   0.000122                0.000006           1.155382e-20
# 6  0.177893   0.542611                0.199451           6.591364e-02
# 7  0.032041   0.076432                0.030958           5.835111e-02
# 8  0.083964   0.335517                0.175334           2.369669e-01
# 9  0.190158   0.538583                0.144385           1.261588e-01
#
#           DSD 4     TSW ROW 5  Storm Water Code Enforcement 6  \
# 0  4.333782e-04  2.201236e-06                    2.128955e-02
# 1  6.433588e-11  6.510865e-11                    1.011546e-02
# 2  0.000000e+00  0.000000e+00                    2.547272e-11
# 3  2.631515e-16  4.131651e-11                    3.029218e-03
# 4  3.958925e-16  1.867478e-10                    1.683632e-01
# 5  0.000000e+00  0.000000e+00                    6.855161e-10
# 6  4.358303e-07  8.785311e-05                    1.404314e-02
# 7  5.920699e-01  6.294120e-03                    2.038543e-01
# 8  6.767166e-05  7.837969e-02                    8.977041e-02
# 9  1.604470e-10  5.482248e-04                    1.668912e-04
#
#          Class_Prediction  Pred      Prob  Actual  Score
# 0                   TSW 0     0  0.457314       1  False
# 1  ESD Complaint/Report 2     2  0.341761       1  False
# 2                   TSW 0     0  0.999074       0   True
# 3  ESD Complaint/Report 2     2  0.898682       0  False
# 4  ESD Complaint/Report 2     2  0.711711       2   True
# 5                   TSW 0     0  0.999872       0   True
# 6               Parking 1     1  0.542611       0  False
# 7                   DSD 4     4  0.592070       1  False
# 8               Parking 1     1  0.335517       1   True
# 9               Parking 1     1  0.538583       1   True
#
# Accuracy Score:  0.486860867793848
#
# Report
#               precision    recall  f1-score   support
#
#            0       0.79      0.41      0.54     80269
#            1       0.35      0.61      0.44     26707
#            2       0.53      0.61      0.56     30255
#            3       0.09      0.24      0.13      3062
#            4       0.01      0.10      0.02       374
#            5       0.03      0.27      0.06       424
#            6       0.17      0.42      0.24      1270
#
#     accuracy                           0.49    142361
#    macro avg       0.28      0.38      0.29    142361
# weighted avg       0.63      0.49      0.52    142361

# %% [markdown]
# It appears the utilzing SMOTE to oversample the dataset did not necessarily increase the model's overall accuracy or class precision probably due to too much noise (it is important to note that it is one of the cons of using SMOTE). We synthesize class observations of DSD that has 900 observations to 180,000 instances.

# %% [markdown]
# # Let's Try Undersampling?

# %% [markdown]
# #### Near-Miss

# %%
nm1 = NearMiss(version=1)
nm_x, nm_y = nm1.fit_resample(trainx,trainy)

# %%
print(sorted(Counter(nm_y).items()))
# Out:
# [(0.0, 872), (1.0, 872), (2.0, 872), (3.0, 872), (4.0, 872), (5.0, 872), (6.0, 872)]

# %%
nn_model.fit(nm_x, nm_y, epochs=10)
# Out:
# Train on 6104 samples
# Epoch 1/10
# 6104/6104 [==============================] - 0s 35us/sample - loss: 1.4069 - accuracy: 0.4866
# Epoch 2/10
# 6104/6104 [==============================] - 0s 30us/sample - loss: 1.1656 - accuracy: 0.5585
# Epoch 3/10
# 6104/6104 [==============================] - 0s 31us/sample - loss: 1.0974 - accuracy: 0.5840
# Epoch 4/10
# 6104/6104 [==============================] - 0s 32us/sample - loss: 1.0598 - accuracy: 0.5945
# Epoch 5/10
# 6104/6104 [==============================] - 0s 32us/sample - loss: 1.0323 - accuracy: 0.6037
# Epoch 6/10
# 6104/6104 [==============================] - 0s 33us/sample - loss: 1.0156 - accuracy: 0.6078
# Epoch 7/10
# 6104/6104 [==============================] - 0s 32us/sample - loss: 1.0013 - accuracy: 0.6121
# Epoch 8/10
# 6104/6104 [==============================] - 0s 31us/sample - loss: 0.9827 - accuracy: 0.6129
# Epoch 9/10
# 6104/6104 [==============================] - 0s 32us/sample - loss: 0.9699 - accuracy: 0.6201
# Epoch 10/10
# 6104/6104 [==============================] - 0s 32us/sample - loss: 0.9645 - accuracy: 0.6204

# %%
test_loss, test_acc = nn_model.evaluate(testx, testy)

print('Test accuracy:', test_acc)
# Out:
# 142361/142361 [==============================] - 2s 17us/sample - loss: 4.5327 - accuracy: 0.1452
# Test accuracy: 0.1451521

# %% [markdown]
# Undersampling the majority classes to 900 instances hindered the model's accuracy due to huge information loss. Because of our results, we will move on and use the train dataset as is, without over or undersampling.

# %% [markdown]
# # Multinomial Logistic Regression

# %%
clf = LogisticRegression(random_state=42,
                         multi_class='multinomial',
                         solver = 'newton-cg')

# %%
mlr_model = clf.fit(trainx, trainy)

# %%
pred_report(mlr_model)
# Out:
# Prediction Report
#
#       TSW 0  Parking 1  ESD Complaint/Report 2  Traffic Engineering 3  \
# 0  0.804353   0.118960                0.033683               0.024707
# 1  0.555609   0.228035                0.061626               0.150315
# 2  0.998893   0.000513                0.000102               0.000090
# 3  0.459199   0.004810                0.507508               0.015240
# 4  0.363620   0.003733                0.626444               0.002744
# 5  0.999195   0.000230                0.000071               0.000084
# 6  0.372926   0.333119                0.258680               0.027621
# 7  0.587597   0.242356                0.131794               0.023164
# 8  0.503937   0.340061                0.107381               0.036503
# 9  0.416735   0.342273                0.202595               0.034900
#
#       DSD 4  TSW ROW 5  Storm Water Code Enforcement 6  \
# 0  0.003568   0.003612                        0.011118
# 1  0.001102   0.001005                        0.002307
# 2  0.000009   0.000166                        0.000228
# 3  0.000154   0.000633                        0.012455
# 4  0.000060   0.000244                        0.003155
# 5  0.000005   0.000046                        0.000370
# 6  0.002012   0.001031                        0.004612
# 7  0.004280   0.003839                        0.006970
# 8  0.000522   0.006595                        0.005001
# 9  0.000529   0.001038                        0.001930
#
#          Class_Prediction  Pred      Prob  Actual  Score
# 0                   TSW 0     0  0.804353       1  False
# 1                   TSW 0     0  0.555609       1  False
# 2                   TSW 0     0  0.998893       0   True
# 3  ESD Complaint/Report 2     2  0.507508       0  False
# 4  ESD Complaint/Report 2     2  0.626444       2   True
# 5                   TSW 0     0  0.999195       0   True
# 6                   TSW 0     0  0.372926       0   True
# 7                   TSW 0     0  0.587597       1  False
# 8                   TSW 0     0  0.503937       1  False
# 9                   TSW 0     0  0.416735       1  False
#
# Accuracy Score:  0.6200223375784099
#
# Report
#               precision    recall  f1-score   support
#
#            0       0.62      0.92      0.74     80269
#            1       0.44      0.17      0.25     26707
#            2       0.76      0.33      0.46     30255
#            3       1.00      0.00      0.00      3062
#            4       0.00      0.00      0.00       374
#            5       0.00      0.00      0.00       424
#            6       0.94      0.21      0.35      1270
#
#     accuracy                           0.62    142361
#    macro avg       0.54      0.23      0.26    142361
# weighted avg       0.62      0.62      0.56    142361

# %% [markdown]
# # Limitations and Assumptions

# %% [markdown]
# The dataset does not account for duplicate requests. For example, if there was a street light out on a populated intersection, chances are many people may report the same problem. However, if there were a dead animal in small alley, not that many would report it.
#
# Just because the street light got more requests does not mean that it occurs more often than other service type requests.
#
# We also have to keep in mind that people report what they want to report. For example, some people may not want to report Graffiti if they think it looks nice. If they report it, it would get taken down so they don't report it.
# +
